# %%
import pandas as pd

# %%
# Read the city data into df
city_df = pd.read_csv('Resources/cities.csv',index_col='City_ID') 
city_df
# Out:
#                    City  Cloudiness Country        Date  Humidity      Lat  \
# City_ID
# 0               andrews          90      US  1613008409       100  32.3187
# 1              mineiros         100      BR  1613008374        95 -17.5694
# 2        severo-kurilsk         100      RU  1613008239        91  50.6789
# 3               mataura         100      NZ  1613008162        87 -46.1927
# 4               lakselv          90      NO  1613008413        86  70.0513
# ...                 ...         ...     ...         ...       ...      ...
# 540               baiao          97      BR  1613009186        94  -2.7906
# 541            catalina          66      US  1613009187        30  32.5056
# 542             boyuibe          69      BO  1613009188        92 -20.4167
# 543              garoua          92      CM  1613009189        20   9.3000
# 544             sarandi          81      BR  1613009190        88 -23.4436
#
#               Lng  Max_Temp  Wind_Speed
# City_ID
# ...

# %%
#push data to html file
city_df.to_html('data.html')
